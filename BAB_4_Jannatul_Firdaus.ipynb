# %% [markdown]
# <a href="https://colab.research.google.com/github/jannatulfirdausnawangw-design/Bab-4-Janna/blob/main/BAB_4_Jannatul_Firdaus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("halo, Janna")
# Out:
# halo, Janna
